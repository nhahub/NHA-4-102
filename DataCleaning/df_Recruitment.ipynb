# %%
import pandas as pd
import numpy as np

# %%
df_Recruitment=pd.read_excel(r"../hire_to_retire_analytics.xlsx",sheet_name="Recruitment")
df_Recruitment.head()
# Out:
#        Req_ID Candidate_ID Employee_ID Pipeline_Status Vacancy_Start_Date  \
# 0  REQ_000001  CAND_000001         NaN  Rejected_Offer                NaT
# 1  REQ_000002  CAND_000002         NaN  Rejected_Offer                NaT
# 2  REQ_000003  CAND_000003         NaN  Rejected_Offer                NaT
# 3  REQ_000004  CAND_000004  EMP_000001           Hired         2018-01-01
# 4  REQ_000005  CAND_000005  EMP_000002           Hired         2018-01-01
#
#    Hire_Date  Days_to_Fill   Sourcing_Channel  Sourcing_Cost  Cost_of_Vacancy  \
# 0        NaT           113  Employee_Referral           1500                0
# 1        NaT            93             Agency          12000                0
# 2        NaT           113          Job_Board           2500                0
# 3 2018-01-01             0  Employee_Referral           1500                0
# 4 2018-01-01             0          Job_Board           2500                0
#
# ...

# %%
df_Recruitment_new=df_Recruitment.copy()

# %%
df_Recruitment_new.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 35714 entries, 0 to 35713
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Req_ID                  35714 non-null  str
#  1   Candidate_ID            35714 non-null  str
#  2   Employee_ID             25000 non-null  str
#  3   Pipeline_Status         35714 non-null  str
#  4   Vacancy_Start_Date      25000 non-null  datetime64[us]
#  5   Hire_Date               25000 non-null  datetime64[us]
#  6   Days_to_Fill            35714 non-null  int64
#  7   Sourcing_Channel        35714 non-null  str
#  8   Sourcing_Cost           35714 non-null  int64
#  9   Cost_of_Vacancy         35714 non-null  int64
#  10  Total_Acquisition_Cost  35714 non-null  int64
#  11  Skill_Score             35714 non-null  float64
#  12  Culture_Score           35714 non-null  float64
#  13  Potential_Score         35714 non-null  float64
# ...

# %%
df_Recruitment_new.shape
# Out:
# (35714, 21)

# %%
df_Recruitment_new.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_Recruitment_new.isnull().sum()
# Out:
# Req_ID                        0
# Candidate_ID                  0
# Employee_ID               10714
# Pipeline_Status               0
# Vacancy_Start_Date        10714
# Hire_Date                 10714
# Days_to_Fill                  0
# Sourcing_Channel              0
# Sourcing_Cost                 0
# Cost_of_Vacancy               0
# Total_Acquisition_Cost        0
# Skill_Score                   0
# Culture_Score                 0
# Potential_Score               0
# LQI                           0
# True_LQI                      0
# Bias_Flag                     0
# Gender                        0
# Ethnicity                     0
# Age_Band                      0
# Education_Level               0
# dtype: int64

# %%
df_Recruitment_new["Employee_ID"]=df_Recruitment_new["Employee_ID"].fillna("Unknown")

# %%
df_Recruitment_new["Hire_Date"]=df_Recruitment_new["Hire_Date"].ffill()

# %%
df_Recruitment_new["Vacancy_Start_Date"]=df_Recruitment_new["Vacancy_Start_Date"].ffill()

# %%
df_Recruitment_new["Vacancy_Start_Date"]=df_Recruitment_new["Vacancy_Start_Date"].bfill()

# %%
df_Recruitment_new["Hire_Date"]=df_Recruitment_new["Hire_Date"].bfill()

# %%
df_Recruitment_new.head(10)
# Out:
#        Req_ID Candidate_ID Employee_ID Pipeline_Status Vacancy_Start_Date  \
# 0  REQ_000001  CAND_000001     Unknown  Rejected_Offer         2018-01-01
# 1  REQ_000002  CAND_000002     Unknown  Rejected_Offer         2018-01-01
# 2  REQ_000003  CAND_000003     Unknown  Rejected_Offer         2018-01-01
# 3  REQ_000004  CAND_000004  EMP_000001           Hired         2018-01-01
# 4  REQ_000005  CAND_000005  EMP_000002           Hired         2018-01-01
# 5  REQ_000006  CAND_000006  EMP_000003           Hired         2018-01-01
# 6  REQ_000007  CAND_000007  EMP_000004           Hired         2018-01-01
# 7  REQ_000008  CAND_000008  EMP_000005           Hired         2018-01-01
# 8  REQ_000009  CAND_000009  EMP_000006           Hired         2018-01-01
# 9  REQ_000010  CAND_000010  EMP_000007           Hired         2018-01-01
#
#    Hire_Date  Days_to_Fill   Sourcing_Channel  Sourcing_Cost  Cost_of_Vacancy  \
# ...

# %%
df_Recruitment_new.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 35714 entries, 0 to 35713
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Req_ID                  35714 non-null  str
#  1   Candidate_ID            35714 non-null  str
#  2   Employee_ID             35714 non-null  str
#  3   Pipeline_Status         35714 non-null  str
#  4   Vacancy_Start_Date      35714 non-null  datetime64[us]
#  5   Hire_Date               35714 non-null  datetime64[us]
#  6   Days_to_Fill            35714 non-null  int64
#  7   Sourcing_Channel        35714 non-null  str
#  8   Sourcing_Cost           35714 non-null  int64
#  9   Cost_of_Vacancy         35714 non-null  int64
#  10  Total_Acquisition_Cost  35714 non-null  int64
#  11  Skill_Score             35714 non-null  float64
#  12  Culture_Score           35714 non-null  float64
#  13  Potential_Score         35714 non-null  float64
# ...

# %%
for col in df_Recruitment_new.columns:
    if df_Recruitment_new[col].dtype=="object":
        df_Recruitment_new[col]=df_Recruitment_new[col].astype("string")

# %%
df_Recruitment_new.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 35714 entries, 0 to 35713
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Req_ID                  35714 non-null  str
#  1   Candidate_ID            35714 non-null  str
#  2   Employee_ID             35714 non-null  str
#  3   Pipeline_Status         35714 non-null  str
#  4   Vacancy_Start_Date      35714 non-null  datetime64[us]
#  5   Hire_Date               35714 non-null  datetime64[us]
#  6   Days_to_Fill            35714 non-null  int64
#  7   Sourcing_Channel        35714 non-null  str
#  8   Sourcing_Cost           35714 non-null  int64
#  9   Cost_of_Vacancy         35714 non-null  int64
#  10  Total_Acquisition_Cost  35714 non-null  int64
#  11  Skill_Score             35714 non-null  float64
#  12  Culture_Score           35714 non-null  float64
#  13  Potential_Score         35714 non-null  float64
# ...

# %%
df_Recruitment_new.describe()
# Out:
#                Vacancy_Start_Date                   Hire_Date  Days_to_Fill  \
# count                       35714                       35714  35714.000000
# mean   2021-06-02 23:26:48.982471  2021-09-06 06:07:36.022848     95.821611
# min           2018-01-01 00:00:00         2018-01-01 00:00:00      0.000000
# 25%           2019-10-31 00:00:00         2020-02-05 00:00:00     87.000000
# 50%           2021-07-19 00:00:00         2021-10-24 00:00:00     98.000000
# 75%           2023-01-27 00:00:00         2023-05-04 00:00:00    107.000000
# max           2024-10-22 00:00:00         2024-12-30 00:00:00    119.000000
# std                           NaN                         NaN     15.402081
#
#        Sourcing_Cost  Cost_of_Vacancy  Total_Acquisition_Cost   Skill_Score  \
# count   35714.000000     35714.000000            35714.000000  35714.000000
# mean     3525.541804     48047.047096            51572.588901     64.840441
# ...

# %%
df_Recruitment_new.to_csv("../CleanedCSVs/df_Recruitment_new.csv",index=False)
